# %% [markdown]
# [<center><img src="images/Logo_I2A2.webp"></center>](https://www.i2a2.academy/)
# **Rev 12**

# %% [markdown]
# # Módulo 2

# %% [markdown]
# # Aula 1 - Parte 2: Jupyter Notebook
#
#
# **Objetivo**: Apresentar o ambiente Jupyter Notebook.

# %% [markdown]
# Este material o auxiliará nas sessões de autoestudo, contudo, fique à vontade para consultar outras fontes de informações, mas nunca deixe de citá-las.

# %% [markdown]
# O **Projeto Jupyter** é uma organização sem fins lucrativos criada para "desenvolver software de código aberto, padrões abertos e serviços para **computação interativa** em dezenas de linguagens de programação". Originado do IPython em 2014, o Projeto Jupyter **suporta ambientes de execução em dezenas de linguagens de programação**. O nome do projeto é uma referência às três principais linguagens de programação suportadas por Jupyter, **Julia, Python e R**, e também uma **homenagem aos cadernos de anotações de Galileu** que registram a descoberta das luas de Júpiter. ([Wikipédia](https://pt.wikipedia.org/wiki/Projeto_Jupyter))

# %% [markdown]
# # Instalando o Jupyter Notebook
# Consulte a [documentação de instalação](https://jupyter.org/install) e instale o **Jupyter Notebook** no seu computador.
# Há duas opções de instalação - utilizando o gerenciador de pacotes PIP ou instalando a [distribuição Anaconda](https://www.anaconda.com/products/individual) - caso você ainda não tenha o [python](https://www.python.org/) instalado em sua máquina, opte em instalar utilizando o Anaconda.

# %%
# !pip install jupyter notebook==6.4.3

# %% [markdown]
# # Utilizando o Jupyter Notebook
#
# * Agora que você já instalou o Jupyter na sua máquina, assista o vídeo abaixo e aprenda como utilizar as funcionalidades e recursos da ferramenta

# %% [markdown]
# [![jupyternotebook](https://img.youtube.com/vi/szP9IRbwO9o/hqdefault.jpg)](https://youtu.be/szP9IRbwO9o "jupyternotebook")

# %% [markdown]
# - Obs.: Provavelmente a aba __nbextensions__, apresenta no vídeo, não deve estar aparecendo no seu Jupyter Notebook :(
# Veja neste [link](https://stackoverflow.com/questions/75498337/adding-jupyter-nbextensions-configurator-to-jupyter-notebook) os detalhes para instalação desta extensão; basicamente envolve o comando abaixo:

# %%
# !pip install jupyter_contrib_nbextensions

# %% [markdown]
# Depois de instalar, atualize seu navegador <F5> e verifique se a aba  __nbextensions__ aparece.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Documentação
#
# Documentação Jupyter Notebook: https://jupyter-notebook.readthedocs.io/en/stable/
#
# Lista de Kernels: https://github.com/jupyter/jupyter/wiki/Jupyter-kernels

# %% [markdown]
# # Arquivos
#
# Notebooks são documentos `JSON` com extensão `.ipynb` (**iPy**thon **N**ote**b**ook)
#
# Trabalha com células:
# * Código
# * [Markdown](https://www.markdownguide.org/getting-started/)

# %% [markdown]
# ## Célula de Código

# %%
# Isto é uma célula de código
print('Imprimindo a saída!')

# %% [markdown]
# ## Célula Markdown
#
# Veja documentação em: https://www.markdownguide.org/cheat-sheet/
#
# - LaTeX com entre dólar ( \\$ ): $P(A|B) = \frac{P(B|A) P(A)}{P(B)}$

# %% [markdown]
# > LaTeX (pronúncia em inglês: [ˈlɑːtɛks] ou [ˈleɪtɛks] uma abreviação de Lamport TeX) é um sistema de preparação de documentos. Ao escrever, o escritor usa texto simples, ao invés do texto formatado encontrado em processadores de texto WYSIWYG como Microsoft Word, LibreOffice Writer e Apple Pages.
# > O LaTeX foi desenvolvido na década de 80, por Leslie Lamport, estando atualmente na versão denominada LaTeX 2e.
# [Fonte](https://pt.wikipedia.org/wiki/LaTeX)

# %% [markdown]
# # Comandos de Células
#
# * Para rodar a célula aperte `Shift + Enter`
# * Modo Comando (azul) `Esc`
# * Modo Edição (verde) `Enter`
# * Para inserir nova célula aperte `a` (para **antes** da célula selecionada) ou `b` (para **depois** da célula selecionada)
# * Para deletar célula aperte duas vezes `d` (delete)
# * Copiar célula(s) selecionada(s) aperte `c` (copy)
# * Colar célula(s) copiada(s) aperte `v` (paste)
# * Mudar tipo:
#     * Code `y`
#     * Markdown `m`

# %% [markdown]
# # Rodando este notebook na nuvem
#
# Para desenvolver e executar seus notebooks na nuvem, você pode utilizar:
# * [GoogleColab](https://research.google.com/colaboratory/intl/pt-BR/faq.html)
# * [myBinder](https://mybinder.org/)
# * [SageMaker Studio Lab](https://studiolab.sagemaker.aws/)

# %% [markdown]
# Utilize este botão para executar este notebook no myBinder
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/vsvasconcelos/i2a2/main?filepath=m2_Jupyter.ipynb)

# %% [markdown]
# Utilize este botão para executar este notebook no Colab
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vsvasconcelos/i2a2/blob/main/m2_Jupyter.ipynb)

# %% [markdown]
# # Comandos `shell`
#
# Use o *bang* `!`

# %%
# Lista arquivos do diretório
# !ls

# %%
# Lista o diretório de trabalho
# !pwd

# %% [markdown]
# # Jupyter Magic
#
# Tem [diversos](https://ipython.readthedocs.io/en/stable/interactive/magics.html)
#
# * `%timeit`: Cronometra o tempo de execução de uma **expressão** `Python`
# * `%%timeit`: Cronometra o tempo de execução de uma **célula**
#
# Execute as células a baixo e verifique o tempo gasto para executá-las:

# %%
# %timeit 3**999999

# %%
# %%timeit
y = 5
x = 3**999999

# %% [markdown]
# # Time everything in IPython

# %%
# !pip install -q ipython-autotime
# %load_ext autotime

# %% [markdown]
# # Formatação Numérica

# %%
10/3

# %%
round(10/3,2)

# %%
"{:,.2f}".format(10/3)

# %%
# %precision %.2f

# %%
10/3

# %% [markdown]
# # Execute o Jupyter no seu computador
# Baixe o arquivo desta aula [m2_Jupyter.ipynb](https://github.com/vsvasconcelos/i2a2/blob/main/m2_Jupyter.ipynb) e execute-o no seu computador.

# %% [markdown]
# # Ciência de Dados com Reprodutibilidade
#
# * Leia o capítulo 1 [Ciência de Dados com Reprodutibilidade usando Jupyter](https://sol.sbc.org.br/livros/index.php/sbc/catalog/download/67/292/544-1?inline=2) do livro [Jornada de Atualização em Informática 2021](https://sol.sbc.org.br/livros/index.php/sbc/catalog/book/67) e explore também o [github](https://github.com/opgabriel/jai2021-jupyter) deste projeto/curso.

# %% [markdown]
# # Bibliotecas
#
# [![numpy](https://img.youtube.com/vi/N0J4Cqn43t8/hqdefault.jpg)](https://youtu.be/N0J4Cqn43t8 "numpy")
#
# **NumPy** (Numerical Python)

# %% [markdown]
# [![pandas](https://img.youtube.com/vi/zHlJY0xuu8M/hqdefault.jpg)](https://youtu.be/zHlJY0xuu8M "pandas")

# %% [markdown]
# # Pandas
# ![image.png](attachment:image.png)

# %% [markdown]
# > pandas é uma **biblioteca** de software criada para a linguagem Python para **manipulação e análise de dados**. Em particular, oferece estruturas e operações para **manipular tabelas numéricas e séries temporais**. É **software livre** sob a licensa licença BSD.[2] O nome é derivado do termo inglês **"panel data"(dados em painel)**, um **termo usado em estatística e econometria para conjunto de dados que incluem várias unidades amostrais** (indivíduos, empresas, etc) acompanhadas **ao longo do tempo**.
# [Fonte](https://pt.wikipedia.org/wiki/Pandas_(software))

# %% [markdown]
# ## Carregando a biblioteca

# %%
# !pip install pandas
import pandas as pd
pd.__version__

# %% [markdown]
# ## Representação da tabela de dados no Pandas
# ![image.png](attachment:image.png)

# %% [markdown]
# - Um DataFrame é uma estrutura de dados bidimensional que pode armazenar dados de diferentes tipos (incluindo caracteres, inteiros, valores de ponto flutuante, dados categóricos e muito mais) em colunas.  É semelhante a uma planilha, uma tabela SQL ou data.frame em R.

# %% [markdown]
# - Cada coluna em um DataFrame é uma Series
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Criando um Dataframe

# %%
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)

# %%
df

# %%
# Verificando o tipo de dado
type(df)

# %% [markdown]
# - Estou apenas interessado em trabalhar com os dados da coluna Idade

# %%
df['Age']

# %%
# Verificando o tipo de dado
type(df['Age'])

# %% [markdown]
# ## Criando uma Series

# %%
ages = pd.Series([22, 35, 58], name="Age")

# %%
ages

# %% [markdown]
# ## Trabalhando com um DataFrame ou Series

# %% [markdown]
# - Qual a Idade (Age) máxima no dataframe df?

# %%
df

# %%
df["Age"].max()

# %%
ages.max()

# %% [markdown]
# - O método **describe()** fornece uma visão geral rápida dos **dados numéricos** em um DataFrame

# %%
df

# %%
df.describe()

# %% [markdown]
# - Como ler e escrer dados tabulares?
# ![image.png](attachment:image.png)

# %%
titanic = pd.read_csv("titanic-data.csv")

# %%
# Mostrando as 3 primeiras linhas
titanic.head(3)

# %%
# Mostrando as 3 últimas linhas
titanic.tail(3)

# %%
# verificando os tipos de dados 
titanic.dtypes

# %% [markdown]
# - Por que **dtypes** não tem parênteses na frente?

# %% [markdown]
#  > [Resposta](https://stackoverflow.com/questions/60855371/why-doesnt-pandas-daframe-shape-have-parentheses)
#    - Atributos
#    - Métodos ( )

# %% [markdown]
# - O que é o tipo de dado **object**

# %%
# verificando informações técnicas do DataFrame
titanic.info()

# %% [markdown]
# - Como selecionar colunas específicas de um DataFrame?
# ![image.png](attachment:image.png)

# %%
titanic

# %%
# Selecionando as idades dos passageiros
ages = titanic["Age"]

# %%
ages

# %%
# Selecionando as idades e o sexo dos passageiros
age_sex = titanic[["Age", "Sex"]]

# %%
age_sex

# %%
age_sex.head()

# %%
# Verificando a forma (shape) da seleção
titanic[["Age", "Sex"]].shape

# %% [markdown]
# - Como filtrar linhas específicas de um DataFrame?
# ![image.png](attachment:image.png)

# %%
# Selecionandos passageiros com idade maior que 35 anos
maior_35 = titanic[titanic["Age"] > 35]
maior_35.head()

# %%
# Quantos são?
maior_35["Age"].count()

# %% [markdown]
# - Como seleciono linhas e colunas específicas de um DataFrame?
# ![image.png](attachment:image.png)

# %%
# Selecionando o sexo dos passageiros com idade maior que 35 anos
maior_35_Sex = titanic.loc[titanic["Age"] > 35, "Sex"]
maior_35_Sex.head()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Veja: [Como usar loc e iloc no pandas?](https://medium.com/horadecodar/data-science-tips-02-como-usar-loc-e-iloc-no-pandas-fab58e214d87)

# %% [markdown]
# - Como faço para criar gráficos no pandas?
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Plotando a idade
titanic["Age"].plot()

# %% [markdown]
# ## Utilizando outro índice para o dataframe

# %%
# Utilizando o campo PassengerId como índice 
titanic = pd.read_csv("titanic-data.csv",index_col='PassengerId')

# %%
titanic.head(3)

# %% [markdown]
# - O registro "Survived" informa se o passageiro sobrevivel (valor 1) ou não (valor 0)

# %%
titanic.Survived.value_counts()

# %% [markdown]
# >  Segundo a Wikipedia das 2224 pessoas a bordo, 1514 perderam suas vidas, enquanto 710 foram salvas.

# %%
len(titanic)

# %% [markdown]
# - A regra internacional de priorizar mulheres e crianças no salvamento foi realizada?

# %%
salvos_sexo_idade = titanic[['Survived', 'Sex', 'Age']]

# %%
len(salvos_sexo_idade)

# %%
salvos_sexo_idade.head(6)

# %%
salvos_sexo_idade.info()

# %% [markdown]
# - Vamos desconsidear registros que possuam dados faltantes

# %%
salvos_sexo_idade=salvos_sexo_idade.dropna()

# %%
len(salvos_sexo_idade)

# %% [markdown]
# - Quantas pessoas sobreviveram na base limpa?

# %%
len(salvos_sexo_idade[salvos_sexo_idade.Survived==1])

# %% [markdown]
# - Na base limpa, quantas mulheres e quantos homens?

# %%
 salvos_sexo_idade.Sex.value_counts()

# %% [markdown]
# - Quantos sobreviventes são mulheres na base limpa?

# %%
len (salvos_sexo_idade[(salvos_sexo_idade.Survived==1) & (salvos_sexo_idade.Sex=='female')])

# %%
#!pip install seaborn
import seaborn as sns
sns.displot(salvos_sexo_idade.Age)
plt.title('Distribuição das idades dos passageiros')

# %%
plt.boxplot([salvos_sexo_idade.Age],1,'gd')
plt.ylabel("Age")
plt.title('BoxPlot da variável idade')

# %% [markdown]
# - Quantas pessoas maiores de 65 anos existem na base?

# %%
len(salvos_sexo_idade[(salvos_sexo_idade.Age >=65)])

# %% [markdown]
# - Destas, quantas sobreviveram?

# %%
len(salvos_sexo_idade[(salvos_sexo_idade.Age >=65) & (salvos_sexo_idade.Survived==1) ])

# %% [markdown]
# - Das 11 pessoas maiores de 65 anos, somente uma sobreviveu.
# Qual seria o sexo destas pessoas?

# %%
salvos_sexo_idade[(salvos_sexo_idade.Sex=='female') & (salvos_sexo_idade.Age >=65) & (salvos_sexo_idade.Survived==1)]

# %%
salvos_sexo_idade.loc[(salvos_sexo_idade.Age >=65) & (salvos_sexo_idade.Survived==1), 'Sex']

# %%
def agrupa (idade):
    """ Realiza classificação etária dos passageiros
    Classifica os passageiros conforme suas idades em: Idoso, Adulto, Adolescente ou Criança.
    Critério: criança <= 11 anos; 18 > adolescente >= 12 anos; 60 >= adulto >= 19 anos; idoso > 60 anos
    
    Argumentos:
            Recebe uma idade            
    Retornos:
            Retorna a idade classificada conforme critério adotado.   
    """
    if idade > 60.0:  
        return 'Idoso'
    elif idade >= 19.0:
        return 'Adulto'
    elif idade >= 12.0:
        return 'Adolescente'
    else:
        return 'Crianca'

# %%
agrupa_por_idade = salvos_sexo_idade.apply(lambda row: agrupa(row['Age']), axis='columns') # axis=1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
agrupa_por_idade_df=pd.DataFrame(agrupa_por_idade, columns=['ClassEtaria'])

# %%
agrupa_por_idade_df.head(10)

# %%
# Concatenando dois dataframes
salvos_sexo_idade=pd.concat([salvos_sexo_idade, agrupa_por_idade_df],axis=1)

# %%
salvos_sexo_idade.head()

# %%
import numpy as np
Y= np.array(salvos_sexo_idade.ClassEtaria.value_counts())
X= [0,1,2,3]
LABELS=['Adulto', 'Adolescente', 'Criança', 'Idoso']
plt.bar(X,Y,align='center')
plt.xticks(X, LABELS)
plt.ylabel("Quantidade")
plt.title('Quantitativo por faixa etaria de passageiro')

# %% [markdown]
#  **Plotly**
# [![bibliotecas](https://img.youtube.com/vi/Oq7y7-bNQkY/hqdefault.jpg)](https://youtu.be/Oq7y7-bNQkY "Plotly")

# %% [markdown]
# # Quer saber mais?
# * Execute os [notebooks](https://github.com/storopoli/ciencia-de-dados) dos Professores Storopoli e Souza
#
# * Assista ...
#
# [![jupyternotebook](https://img.youtube.com/vi/ZC8bfSZLl80/hqdefault.jpg)](https://youtu.be/ZC8bfSZLl80 "jupyternotebook")
#
# * Veja o [Tutorial Jupyter Notebook](https://www.datacamp.com/community/tutorials/tutorial-jupyter-notebook#gs.N0CbFZI)
#
# [![jupyternotebook](https://img.youtube.com/vi/Z-zwFha2Oco/hqdefault.jpg)](https://youtu.be/Z-zwFha2Oco "Prepare seus dados brutos para análise usando Jupyter Notebooks")
#
#
# # O Futuro do Trabalho: 10 habilidades que vão estar em alta até 2025
#
# Segundo o relatório [Future of Jobs: The top 10 skills to be developed by 2025](http://www3.weforum.org/docs/WEF_Future_of_Jobs_2020.pdf), do Fórum Econômico Mundial, **Pensamento crítico** é a 4ª principal habilidade que estará em alta até 2025.
#
# # Pensamento Crítico
#
# Pesquise no artigo [COMPETÊNCIAS RELEVANTES PARA O PROFISSIONAL DO FUTURO - COMPETÊNCIAS LISTADAS PELO RELATÓRIO “THE FUTURE OF JOB” DO FÓRUM ECONÔMICO MUNDIAL E A PREVISÃO DE FUTURO DE YUVAL HARARI](https://pt.scribd.com/document/565301777/artigo-semana-academica-daniele-rodrigues-v2-1-pdf) e no e-book [O Guia Definitivo das Competências](https://materiais.qulture.rocks/guia-das-competencias) sobre o **Pensamento crítico**.
#
#    - Assista aos vídeos ...
#
# [![Pensamento Critico](https://img.youtube.com/vi/azCTNyzCZBM/hqdefault.jpg)](https://youtu.be/azCTNyzCZBM "Pensamento Crítico: Lógica e argumentação, com Prof. Walter Carnielli")
#
#    - Indução, Logica e Probabilidade - Uma aula de Walter Carnielli
#
# [![Pensamento Critico](https://img.youtube.com/vi/-XZD3WKDmyo/hqdefault.jpg)](https://youtu.be/-XZD3WKDmyo "Indução, Logica e Probabilidade - Uma aula de Walter Carnielli")
#
# [Criatividade e Pensamento Crítico - Instituto Ayrton Senna](https://institutoayrtonsenna.org.br/o-que-defendemos/criatividade-e-pensamento-critico/)
#
# # Pensamento Crítico x Pensamento Sistêmico
#
# * Explore o portal [Pensamento Sistêmico](https://colaborae.com.br/blog/2021/12/16/pensamento-analitico-2/)
#
# * Assistas aos vídeos ...
#
#     - Uma história sobre sistemas (Pensamento sistêmico)
#
# [![Pensamento sistemico](https://img.youtube.com/vi/rWbsE3qQu1I/hqdefault.jpg)](https://youtu.be/rWbsE3qQu1I "Uma história sobre sistemas (Pensamento sistêmico)")
#
#    - Pensamento sistêmico
#
# [![Pensamento sistemico](https://img.youtube.com/vi/YDOjWT2Ix-g/hqdefault.jpg)](https://youtu.be/YDOjWT2Ix-g "Pensamento sistemico ENAP")
#
#    - O processo de design na Engenharia
#
# [![processo de design](https://img.youtube.com/vi/yZc2ympulEA/hqdefault.jpg)](https://youtu.be/yZc2ympulEA "processo de design")
#
# * Leia o artigo [Um Mapa Conceitual sobre Pensamento Sistêmico:
# seus Conceitos e Autores](./docs/um-mapa-conceitual-sobre-pensamento-sistemico_compress-1.pdf)
#
# * Explore o portal [o que você queria saber sobre pensamento sistêmico (e nem sabia)](https://www.enap.gov.br/pt/acontece/noticias/especial-o-que-voce-queria-saber-sobre-pensamento-sistemico-e-nem-sabia)
#
#
# # Gosta de livros
#
# [Jupyter Guide to Linear Algebra](https://bvanderlei.github.io/jupyter-guide-to-linear-algebra/intro.html)
#
# [Teaching and Learning with Jupyter](https://jupyter4edu.github.io/jupyter-edu-book/)
#
# [Python Programming for Data Science](https://www.tomasbeuzen.com/python-programming-for-data-science/README.html)
#
# [Books with Jupyter](https://executablebooks.org/en/latest/gallery/)
#
# [Desvendando Sistemas (Pensamento Sistêmico) João Alberto Amaral](https://edisciplinas.usp.br/pluginfile.php/5661115/mod_resource/content/1/DesvendandoSistemasPDFweb1JoaoArantes.pdf)
#
# [Design ágil para inovação social e desenvolvimento - Bruno e Tomaz](https://repositorio.enap.gov.br/handle/1/5647)
#
#
# # Referências:
#    [1] Storopoli & Souza (2020). Ciência de Dados com Python: pandas, matplotlib, Scikit-Learn, TensorFlow e PyTorch. Retrieved from https://github.com/storopoli/ciencia-de-dados
#
#    [2] Falha [libxml2](https://stackoverflow.com/questions/34232887/cant-install-python-lxml-and-libxml2-on-windows) no Windows

# %% [markdown]
# Qualquer dúvida, poste no fórum da disciplina.
#    - Te vejo na mentoria!
